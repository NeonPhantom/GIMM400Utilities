# %%
def string_func(input_string):
  
    #Takes the input string and returns the number of words in the string
    num_words = len(input_string.split())
    return num_words

print(string_func("Hello and hi to you"))
# Out:
# 5
